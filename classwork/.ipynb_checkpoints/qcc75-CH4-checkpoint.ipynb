# %%
import math
import numpy as np

my_pi = 0

for i in range(0, 5000):
    term = ((-1)**i) / (2 * i + 1)
    my_pi += 4 * term
    
    if ((i + 1) % 100 == 0):
        error = abs(my_pi - np.pi) / np.pi   # relative error= absolute value(calculated - actual)/actual
        print(i + 1, my_pi, error)
# Out:
# 100 3.1315929035585537 0.00318301929431018
# 200 3.136592684838816 0.001591539484045989
# 300 3.1382593295155914 0.001061030006672841
# 400 3.1390926574960143 0.0007957734720706582
# 500 3.139592655589785 0.000636619135750372
# 600 3.139925988080531 0.0005305161085596649
# 700 3.1401640828900845 0.00045472817682973846
# 800 3.1403426540780757 0.00039788720230457477
# 900 3.140481542821618 0.000353677542155349
# 1000 3.140592653839794 0.0003183098066059948
# 1100 3.1406835628685323 0.00028937256401525733
# 1200 3.1407593204011373 0.0002652581924342223
# 1300 3.140823422934354 0.00024485372238193846
# 1400 3.1408783679666143 0.0002273641754167515
# 1500 3.1409259869971993 0.00021220656721108246
# 1600 3.1409676536508284 0.00019894365943672938
# 1700 3.1410044183465597 0.00018724109332290856
# 1800 3.1410370980771027 0.0001768388120132509
# 1900 3.141066337836765 0.0001675315074430701
# 2000 3.1410926536210413 0.0001591549331452938
# 2100 3.1411164631405977 0.0001515761276852106
# ...
