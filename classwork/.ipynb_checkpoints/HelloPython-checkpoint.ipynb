# %%
print("Hello World!")
# Out:
# Hello World!

# %%
number 1 = 5.0/2
number 2 = 5/2
# Out:
#   File "<ipython-input-2-6cdc8d308e85>", line 1
#     number 1 = 5.0/2
#            ^
# SyntaxError: invalid syntax

# %%
numIn= input ("enter a number")
# Out:
# enter a number5

# %%
print(type(numIn))
# Out:
# <class 'str'>

# %%
myfile = open("test.dat", 'w')
myfile.write(numIn)
myfile.write("\n")
myfile.write("Hello World\n")
myfile.close()

# %%
print(b!=a or b<a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-803d80cf3eee> in <module>
# ----> 1 print(b!=a or b<a)
#
# NameError: name 'b' is not defined

# %%
a = 2
b = 3

# %%
print(b!=a or b<a)
# Out:
# True

# %%
print( b==a or b<a)
# Out:
# False

# %%
if (a>b) print ("A is greater than B")
# Out:
#   File "<ipython-input-10-fbe89b5d8730>", line 1
#     if (a>b) print ("A is greater than B")
#              ^
# SyntaxError: invalid syntax

# %%
if (a<b) print ("B is greater than A")
# Out:
#   File "<ipython-input-11-d45daa2b9e42>", line 1
#     if (a<b) print ("B is greater than A")
#              ^
# SyntaxError: invalid syntax

# %%
if (a<b):print ("B is greater than A")
# Out:
# B is greater than A

# %%
if (b<a) :
    print ("B is less than A")
    print ("Conditionals are awesome")

# %%
for r in range (1, 3):
    print (r, r**2)
# Out:
# 1 1
# 2 4

# %%
mylist = ["Charlie", 10, "yellow", 42, "black"]

# %%
print(mylist[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-a140bbf0a41c> in <module>
# ----> 1 print(mylist[5])
#
# IndexError: list index out of range

# %%
print("Charlie" in mylist)
# Out:
# True

# %%
def calc_hyp(a, b)
    h = math.sqrt (a*a, b*b)
    returh h
# Out:
#   File "<ipython-input-20-7986eab51e0c>", line 1
#     def calc_hyp(a, b)
#                       ^
# SyntaxError: invalid syntax

# %%
import math

def calc_hyp(a, b):
    h = math.sqrt (a*a + b*b)
    return h

# %%
import random

def montecarlo_pi(number_of_shots):
    for i in range (0,number_of_shots):
        x = 1
        y = 1
        return

# %%
montecarlo_pi(50)

# %%
import random

def montecarlo_pi(number_of_shots):
    number_of_hits = 0
    for i in range(0, number_of_shots):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)

        if (x*x + y*y < 1):
            number_of_hits = number_of_hits + 1

    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(100000000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-cb0fae0eda01> in <module>
# ----> 1 montecarlo_pi(100000000)
#
# <ipython-input-28-64d3358148d3> in montecarlo_pi(number_of_shots)
#       8
#       9         if (x*x + y*y < 1):
# ---> 10             number_of_hits = counter + 1
#      11
#      12     return 4*counter/number_of_shots
#
# NameError: name 'counter' is not defined

# %%
import random

def montecarlo_pi(number_of_shots):
    number_of_hits = 0
    for i in range(0, number_of_shots):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)

        if (x*x + y*y < 1):
            number_of_hitts = counter + 1

    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(100000000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-cb0fae0eda01> in <module>
# ----> 1 montecarlo_pi(100000000)
#
# <ipython-input-31-a4ebc148ae8b> in montecarlo_pi(number_of_shots)
#       8
#       9         if (x*x + y*y < 1):
# ---> 10             number_of_hitts = counter + 1
#      11
#      12     return 4*number_of_hits/number_of_shots
#
# NameError: name 'counter' is not defined

# %%
import random

def montecarlo_pi(number_of_shots):
    number_of_hits = 0
    for i in range(0, number_of_shots):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)

        if (x*x + y*y < 1):
            number_of_hits = number_of_hits + 1

    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(100000000)
# Out:
# 3.1413978
