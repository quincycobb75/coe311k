# %%
import numpy as np

# %%
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

# %%
print (v1)
print (v2)
# Out:
# [1 2 3]
# [4 5 6]

# %%
v_add = v1 + v2
v_sub = v1 - v2

# %%
print (v_add)
print (v_sub)
# Out:
# [5 7 9]
# [-3 -3 -3]

# %%
scalar = 2
v_scaled = scalar * v1

# %%
print (v_scaled)
# Out:
# [2 4 6]

# %%
dot_product = np.dot(v1, v2)

# %%
print (dot_product)
# Out:
# 32

# %%
magnitude_v1 = np.linalg.norm(v1)

# %%
print (magnitude_v1)
# Out:
# 3.7416573867739413

# %%
C = np.array ([1, 2, 3], [4, 5, 6])
matrix_add = A + C
matrix_add = A - C

print ("A+C=\n", matrix_add)
print ("A-C=\n", matrix_sub)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c95574b58f4c> in <module>
# ----> 1 C = np.array ([1, 2, 3], [4, 5, 6])
#       2 matrix_add = A + C
#       3 matrix_add = A - C
#       4
#       5 print ("A+C=\n", matrix_add)
#
# TypeError: data type not understood

# %%
matrix_mul = np.dot(A, B)

print (matrix_mul)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2f6ae5821938> in <module>
# ----> 1 matrix_mul = np.dot(A, B)
#       2
#       3 print (matrix_mul)
#
# NameError: name 'A' is not defined

# %%
A = np.array([[1, 2, 3], [4, 5, 6]])
print("Matrix A:\n", A)
# Out:
# Matrix A:
#  [[1 2 3]
#  [4 5 6]]

# %%
B = np.array([[7, 8, 9], [10, 11, 12], [13, 14, 15]])
print("Matrix B:\n", B)
# Out:
# Matrix B:
#  [[ 7  8  9]
#  [10 11 12]
#  [13 14 15]]

# %%
matrix_mul = np.dot(A, B)

print (matrix_mul)
# Out:
# [[ 66  72  78]
#  [156 171 186]]

# %%
transpose_A = A.T
print (transpose_A)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
A = np.array ([[2,3,0], [4,-1,0], [1,1,0]])
b = np.array ([5,3,2])

print (A)
print (b)

x = np.linalg.solve(A,b)
print ("solution (x, y): ",x)
# Out:
# [[ 2  3  0]
#  [ 4 -1  0]
#  [ 1  1  0]]
# [5 3 2]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-19-4a7fc5462f0f> in <module>
#       5 print (b)
#       6
# ----> 7 x = np.linalg.solve(A,b)
#       8 print ("solution (x, y): ",x)
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/numpy/linalg/linalg.py in solve(a, b)
#     401     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     402     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 403     r = gufunc(a, b, signature=signature, extobj=extobj)
#     404
#     405     return wrap(r.astype(result_t, copy=False))
#
# /opt/conda/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      95
#      96 def _raise_linalgerror_singular(err, flag):
# ---> 97     raise LinAlgError("Singular matrix")
#      98
#      99 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
A = np.array ([[2, 1], [1, 2]])
e_value, e_vectors = np.linalg.eig(A)

# %%
print ("eigenvalue:", e_value)
print ("eigenvector:", e_vector)
# Out:
# eigenvalue: [3. 1.]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-aabac4d355e2> in <module>
#       1 print ("eigenvalue:", e_value)
# ----> 2 print ("eigenvector:", e_vector)
#
# NameError: name 'e_vector' is not defined

# %%
A = np.array ([[4, 7], [2, 6]])
